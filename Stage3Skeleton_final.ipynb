# %%
import torch
import copy
import numpy as np
import itertools
import random
from matplotlib import pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

# %%
import matplotlib
from tqdm import tqdm
matplotlib.use("TkAgg")
BOLD = "\033[1m"
RESET = "\033[0m"

# %% [markdown]
# ### Multi-Agent Reinforcement Learning Environment for Package Delivery
#
# This class defines an environment where multiple agents work together to pick up, handover and deliver packages.
#
# **Attributes:**
# - reward_pickup (int): Reward for picking up a package.
# - reward_deliver (int): Reward for successfully delivering a package.
# - reward_handover (int): Reward for a successful handover between agents.
# - reward_move (int): Reward for a regular movement action.
# - reward_stuck (int): Penalty for an agent getting stuck.
# - Initial location coordinated of the agents are defined in: agentsA_coord and agentsB_coord
# - package collected or not for botht types of agents is defines in:  agentsA_collect and agentsB_collect.
# - agentsA_step (list of int): Number of steps taken by agents in group A.
# - agentsB_step (list of int): Number of steps taken by agents in group B.
# - test_length (int): Counter to keep track of agent steps which is required for reward calculation later.
# - packages_delivered (int): Number of packages successfully delivered.
#
# **Methods:**
# - reset_env(): Reset the environment to its initial state.
# - get_state(): Get the current state of the environment as a NumPy array.
# - move_agent(actionA, actionB): Move agents according to the specified actions and update rewards.
# - get_grid(): Get the current grid representation.
# - setup_grid(): Set up the initial grid with agents and locations.
# - plot_grid(snapshot, ax=None): Visualize the current state of the environment.
#
# **Purpose of this class:**
# The purpose of the `Environment` class is to define and manage the simulation environment for a multi-agent reinforcement learning scenario where agents are tasked with picking up, handing over and delivering packages in a grid-based world. This class serves as the foundation for creating and controlling the environment in which agents interact and learn.
#
# 1. **Grid-Based Simulation:** The class creates a grid-based environment with specified dimensions where the agents operate. It sets up the grid and initial positions of key elements within the environment.
#
# 2. **Agent Interaction:** The class facilitates interactions between multiple agents (groups A and B) by allowing them to take actions and move within the grid. Agents can perform actions like picking up, delivering, or moving.
#
# 3. **Reward Management:** The class handles reward calculation for agents based on their actions. Agents receive rewards for successful package pickup, delivery, and handovers, while also incurring penalties for movement and getting stuck.
#
# It is the foundation of creating a controlled environment in which agents can learn and make decisions while engaging in a package delivery task. It provides a structured framework for the multi-agent reinforcement learning algorithm.

# %%
class Environment():
    
    #fields:
    #a grid of size defined by parameter
    #b, a tuple repsenting the delivery location
    #a, a tuple representing the package location
    #size, an int representing the horizontal and vertical dimensions of the grid
    def __init__(self, size:int, verbose=0):
        self.size = size
        self.actions = ['north', 'south', 'west', 'east']
        self.reward_pickup = 500
        self.reward_deliver = 500
        self.reward_handover = 1000
        self.reward_move = -5
        self.reward_stuck = -100
        self.reset_env()
        self.verbose = verbose
    
    def reset_env(self):
        self.a=(0,0)
        self.b=(self.size-1,self.size-1)
        
        combinations = list(itertools.product(list(range(self.size)), repeat=2))
        # Remove (0, 0) and (size-1, size-1)
        combinations = [(x, y) for x, y in combinations if (x, y) != (0, 0) and (x, y) != (self.size-1, self.size-1)]
        # rd.shuffle(combinations)
        agentA1, agentA2, agentB1, agentB2 = random.sample(combinations, 4)
        self.agentsA_coord = [agentA1, agentA2]
        self.agentsB_coord = [agentB1, agentB2]

        self.agentsA_collect = [0,0]
        self.agentsB_collect = [0,0]

        self.terminated = False

        self.agentsA_step = [0,0]
        self.agentsB_step = [0,0]
        self.test_length = 0

        self.packages_delivered = 0

        self.setup_grid()

    # def coordinates_to_noisy_ohv(self, coordinate:int):
    #     ohv = np.zeros(4)
    #     noise = np.random.normal(-1e-5, 1e-5, ohv.shape)
    #     ohv[coordinate] = 1
    #     ohv = ohv + noise
    #     return ohv
    #     this is a legacy method from a one-hot representation of it
    


    def get_state(self):
        #This method previously unpacked the coordinates into a tuple which can be used to index the qmatrix or for easy incorporation to the Deep Q Network
        return np.array([self.agentsA_coord[0][0],self.agentsA_coord[0][1],self.agentsA_coord[1][0],self.agentsA_coord[1][1],
                         self.agentsB_coord[0][0],self.agentsB_coord[0][1],self.agentsB_coord[1][0],self.agentsB_coord[1][1],
                         self.agentsA_collect[0], self.agentsA_collect[1], self.agentsB_collect[0], self.agentsB_collect[1]])

    
    #Method which updates the location of the agent on the grid. Currently just zeroes whatever it landed on - can include other logic instead
    def move_agent(self, actionA, actionB):
        x, y = self.a
        self.grid[x, y] = 1  # Place "a" on the grid
        x, y = self.b
        self.grid[x, y] = 2  # Place "b" on the grid

        agentsA_reward = [0,0]
        agentsB_reward = [0,0]
        agentsA_deliver = [0,0]
        agentsB_deliver = [0,0]

        for i in range(len(self.agentsA_step)):
            self.agentsA_step[i] += 1
        for i in range(len(self.agentsB_step)):
            self.agentsB_step[i] += 1
        
        self.test_length += 1

        agentsA_coord_old = self.agentsA_coord
        agentsB_coord_old = self.agentsB_coord

        #Assign new coordinates for agent A to exist at
        for i in range(len(self.agentsA_coord)):
            new_x, new_y = self.agentsA_coord[i]
            if actionA[i] == 'north' and self.agentsA_coord[i][1] > 0:
                new_y -= 1
            elif actionA[i] == 'south' and self.agentsA_coord[i][1] < self.size - 1:
                new_y += 1
            elif actionA[i] == 'west' and self.agentsA_coord[i][0] > 0:
                new_x -= 1
            elif actionA[i] == 'east' and self.agentsA_coord[i][0] < self.size - 1:
                new_x += 1

            #Update the grid based on new agent coordinates
            self.grid[self.agentsA_coord[i]] = 0
            self.agentsA_coord[i] = (new_x, new_y)
            self.grid[self.agentsA_coord[i]] = 3

        #Assign new coordinates for agent B to exist at
        for i in range(len(self.agentsB_coord)):
            new_x, new_y = self.agentsB_coord[i]
            if actionB[i] == 'north' and self.agentsB_coord[i][1] > 0:
                new_y -= 1
            elif actionB[i] == 'south' and self.agentsB_coord[i][1] < self.size - 1:
                new_y += 1
            elif actionB[i] == 'west' and self.agentsB_coord[i][0] > 0:
                new_x -= 1
            elif actionB[i] == 'east' and self.agentsB_coord[i][0] < self.size - 1:
                new_x += 1

            #Update the grid based on new agent coordinates
            self.grid[self.agentsB_coord[i]] = 0
            self.agentsB_coord[i] = (new_x, new_y)
            self.grid[self.agentsB_coord[i]] = 4
        
        # Agent A:
        for i in range(len(self.agentsA_coord)):
            if self.agentsA_collect[i] == 0:
                if self.agentsA_coord[i] == self.a:
                    if self.verbose>2:
                        print("A{} pickup".format(i))
                    self.agentsA_collect[i]=1
                    agentsA_reward[i] = self.reward_pickup
                else:
                    agentsA_reward[i] = self.reward_move 
            else:
                for j in range(len(self.agentsB_coord)):
                    if self.agentsA_coord[i] == agentsB_coord_old[j]:
                        if self.agentsB_coord[j] == agentsA_coord_old[i]:
                            if self.agentsB_collect[j] == 0:
                                if self.agentsA_collect[i] == 1:
                                    self.agentsA_collect[i]=0
                                    agentsA_deliver[i]=1
                                    self.agentsB_collect[j]=1
                                    agentsA_reward[i] = self.reward_handover - ((np.abs(self.agentsA_coord[i][0] - self.a[0]) + np.abs(self.agentsA_coord[i][1] - self.a[1])) ** 2)
                                    agentsB_reward[j] = self.reward_handover - ((np.abs(self.agentsB_coord[j][0] - self.b[0]) + np.abs(self.agentsB_coord[j][1] - self.b[1])) ** 2)
                                    if self.verbose>2:
                                        print("A{} B{} handover".format(i,j))
                                        print("\tagentsA_reward",agentsA_reward[i], self.agentsA_step[i])
                                        print("\tagentsB_reward",agentsB_reward[j], self.agentsB_step[j])
                                    self.agentsA_step[i]=0 ; self.agentsB_step[j]=0

                if agentsA_deliver[i]==0:
                    agentsA_reward[i] = self.reward_move 

        # Agent B:
        for i in range(len(self.agentsB_coord)):
            if self.agentsB_collect[i] == 1:
                if self.agentsB_coord[i] == self.b:
                    if self.verbose>2:
                        print("B{} deliver".format(i))
                    agentsB_deliver[i]=1
                    self.agentsB_collect[i]=0
                    agentsB_reward[i] = self.reward_deliver
                    self.packages_delivered += 1
                else:
                    agentsB_reward[i] = self.reward_move 
            else:
                agentsB_reward[i] = self.reward_move 

        if self.test_length > 200:
            if self.verbose>2:
                print("terminated")
            self.terminated = True

        if self.verbose>3:
            print("agentsA_reward",agentsA_reward)
            print("agentsB_reward",agentsB_reward)

        return agentsA_reward, agentsB_reward, agentsA_deliver, agentsB_deliver, self.packages_delivered, self.terminated

    def get_grid(self):
        return self.grid.tolist()

    #method to set up the original grid including a location
    def setup_grid(self):
        self.grid = np.zeros((self.size, self.size))
            
        x, y = self.a
        self.grid[x, y] = 1  # Place "a" on the grid

        x, y = self.b
        self.grid[x, y] = 2  # Place "b" on the grid

        # Place the "home" location (0) on the grid
        for i in range(len(self.agentsA_coord)):
            x, y = self.agentsA_coord[i]
            self.grid[x, y] = 3

        for i in range(len(self.agentsB_coord)):
            x, y = self.agentsB_coord[i]
            self.grid[x, y] = 4
    
    def plot_grid(self, snapshot, ax=None):
        if ax is None:
            fig, ax = plt.subplots()
            ax.set_facecolor('white')
        else:
            ax.clear()

        # Plot the grid
        ax.imshow(np.array([[0]]), cmap="bone", extent=[0, self.size, 0, self.size])

        for i in range(self.size):
            for j in range(self.size):
                cell_value = snapshot[i][j]
                images_to_display = []

                if cell_value == 3:
                    images_to_display.append(OffsetImage(agent_img, zoom=0.08, alpha=0.5))
                elif cell_value == 4:
                    images_to_display.append(OffsetImage(agent_img2, zoom=0.05, alpha=0.5))
                elif cell_value == 1:
                    images_to_display.append(OffsetImage(package_img, zoom=0.03, alpha=0.75))
                elif cell_value == 2:
                    images_to_display.append(OffsetImage(destinationB_img, zoom=0.05, alpha=0.75))

                for image in images_to_display:
                    ab = AnnotationBbox(image, (j + 0.5, self.size - i - 0.5), frameon=False)
                    ax.add_artist(ab)

        # Set axis properties
        ax.set_xlim(0, self.size)
        ax.set_ylim(0, self.size)
        ax.set_xticks(np.arange(self.size) + 1)
        ax.set_yticks(np.arange(self.size) + 1)
        ax.set_xticklabels([])
        ax.set_yticklabels([])
        ax.grid(True, linewidth=2, color='white')

        # Set title
        ax.set_title("Package Delivery Agent")

        return ax
agent_img = plt.imread('agent.jpg')
agent_img2 = plt.imread("agent2.png")
package_img = plt.imread('package.jpg')
destinationB_img = plt.imread('destinationB.jpg')

# %% [markdown]
# ### Deep Q-Network (DQN) for RL
#
# This class defines a DQN model for reinforcement learning tasks. It consists of a neural network that approximates Q-values for state-action pairs and supports training and target network updates. This the the DQN which will be used to train both type of Agents (A and B).
#
# **Attributes:**
# - model (torch.nn.Sequential): The main neural network model for Q-value approximation.
# - model2 (torch.nn.Sequential): A target network with the same architecture as the main model.
# - loss_fn (torch.nn.MSELoss): Mean Squared Error loss function for training.
#
# **Methods:**
# - update_target(): Copy the state of the prediction network to the target network.
# - get_qvals(next_state): Get Q-values for the next state based on the prediction network.
# - get_maxQ(state): Get the maximum Q-value for a state based on the target network.
# - train_one_step(states, actions, targets): Perform a single training step with provided minibatches.
#
# **Purpose of this class:**
# The purpose of the `DQN` class is to provide a framework for creating and training Deep Q-Networks (DQNs) for reinforcement learning tasks for both type of Agents.
#
# 1. **Neural Network Model:** The class defines a neural network model that approximates Q-values for state-action pairs. This model is the main part of the DQN and is used for making action predictions.
#
# 2. **Target Network:** The class includes a target network, which is a copy of the main model. This target network is periodically updated with the state of the prediction network to stabilize training.
#
# 3. **Loss Function:** It provides a Mean Squared Error (MSE) loss function, used to calculate the loss during training. The loss quantifies the error between predicted Q-values and target Q-values.
#
# 4. **Training:** The class offers a method (`train_one_step`) for performing a single training step. It updates the model's weights based on a minibatch of states, actions, and corresponding TD (Temporal Difference) targets. This training process enables the model to learn optimal Q-values.
#
# 5. **Q-Value Computation:** It provides methods for calculating Q-values. The `get_qvals` method computes Q-values for a given state-action pair based on the prediction network, while the `get_maxQ` method finds the maximum Q-value for a state based on the target network.
#
# 6. **Target Network Update:** The class includes a method (`update_target`) for synchronizing the target network with the prediction network. This process is crucial for stabilizing training in reinforcement learning.

# %%
class DQN:
    def __init__(self, learning_rate, state_size=100, action_size = 4):
        l1 = state_size
        l2 = 24
        l3 = 24
        l4 = action_size
        self.model = torch.nn.Sequential(
        torch.nn.Linear(l1, l2),
        torch.nn.ReLU(),
        torch.nn.Linear(l2, l3),
        torch.nn.ReLU(),
        torch.nn.Linear(l3,l4))

        self.model2 = copy.deepcopy(self.model)
        self.model2.load_state_dict(self.model.state_dict())
        self.loss_fn = torch.nn.MSELoss()
        self.learning_rate = learning_rate
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.learning_rate)

# The function "update_target" copies the state of the prediction network to the target network. You need to use this in regular intervals.
    def update_target(self):
        self.model2.load_state_dict(self.model.state_dict())

# The function "get_qvals" returns a numpy list of qvals for the next_state given by the argument based on the prediction network.
    def get_qvals(self, next_state):
        state1 = torch.from_numpy(next_state).float()
        qvals_torch = self.model(state1)
        qvals = qvals_torch.data.numpy()
        return qvals

# The function "get_maxQ" returns the maximum q-value for the state given by the argument based on the target network.
    def get_maxQ(self,state):
        return torch.max(self.model2(torch.from_numpy(state).float())).float()

# The function "train_one_step_new" performs a single training step.
# It returns the current loss (only needed for debugging purposes).
# Its parameters are three parallel lists: a minibatch of states, a minibatch of actions,
# a minibatch of the corresponding TD targets and the discount factor.
    def train_one_step(self, states, actions, targets):
        targets_reply = []
        state1_batch = torch.from_numpy(states).float()
        # state1_batch = torch.cat([torch.from_numpy(s).float() for s in states])
        action_batch = torch.Tensor(actions)
        Q1 = self.model(state1_batch)
        X = Q1.gather(dim=1,index=action_batch.long().unsqueeze(dim=1)).squeeze()
        Y = torch.tensor(targets).float()
        loss = self.loss_fn(X, Y)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        return loss.item()

# %% [markdown]
# #### AGENT A CLASS
#
# The AgentA class is a subclass of the DQN class for type A agents. It represents an agent that can interact with an environment, learn from experiences, and make decisions using Q-learning.
#
# **Attribites**:
# - statespace_size (int): The size of the state space.
# - gamma (float): The discount factor for future rewards.
# - learning_rate (float): The learning rate used for updating the Q-network.
# - start_epsilon (float): The initial exploration rate (epsilon-greedy strategy).
# - epsilon_decay_factor (float): The factor by which epsilon is decayed over time.
# - min_epsilon (float): The minimum value for epsilon.
# - replay_buffer_size (int): The size of the replay buffer for experience replay.
# - batch_size (int): The size of mini-batches for training the network.
# - network_copy_frequency (int): The frequency at which the target network is updated.
#
# **Method**:
# - remember(self, state, actionA, agentsA_reward, agentsA_deliver, next_state): Stores a transition (experience) in the agent's memory.
# - update_target(self): Updates the target Q-network based on the defined network_copy_frequency. It calls the update_target method from the parent class DQN.
# - act(self, state): Decides the action to take in the current state using an epsilon-greedy strategy. It explores with probability epsilon and exploits with probability 1 - epsilon.
# - process_minibatch(self, minibatch): Prepares the data for updating the Q-network based on a mini-batch of experiences.
# - save_model_parameters(self, destination): Saves the model parameters of the agent's Q-network to a specified file.
# - load_model_parameters(self, path): Loads model parameters for the agent's Q-network from a specified file.
#
# **Purpose of this class**:
#
# 1. DQN Implementation: It is an implementation of the Deep Q-Network (`DQN`) algorithm, which is a popular method for solving reinforcement learning problems by approximating the optimal action-value function.
#
# 2. Experience Storage: The `remember` method is responsible for storing experiences (state, action, reward, delivery flag, next state) in the agent's memory. Experience replay is a key feature of DQN algorithms, which helps the agent learn from past experiences.
#
# 3. Epsilon-Greedy Policy: The `act` method implements an epsilon-greedy policy for action selection. It balances exploration (taking random actions) and exploitation (choosing the action with the highest estimated Q-value).
#
# 4. Network Update: The `update_target` method is responsible for updating the target Q-network. In DQN, there are typically two Q-networks: one for learning (the primary network) and one for target values. The target network is periodically updated to stabilize training.
#
# 5. Mini-Batch Processing: The `process_minibatch` method prepares the data for training the Q-network using mini-batches of experiences. It computes target Q-values for each experience, which are used to update the network.

# %%
class AgentA(DQN):
    def __init__(self, statespace_size=12, gamma=0.99, learning_rate=0.997, start_epsilon=1.0,
                 epsilon_decay_factor=0.999, min_epsilon=0.05, replay_buffer_size=10000,
                 batch_size=200, network_copy_frequency=10):
        super().__init__(learning_rate=learning_rate, state_size=statespace_size, action_size=4)  # Call the parent constructor
        self.statespace_size = statespace_size
        self.gamma = gamma
        # self.learning_rate = learning_rate
        self.memory = []  # Using a list instead of a deque
        self.epsilon = start_epsilon
        self.epsilon_min = min_epsilon
        self.epsilon_decay_factor = epsilon_decay_factor
        self.replay_buffer_size = replay_buffer_size
        self.batch_size = batch_size
        self.network_copy_frequency = network_copy_frequency
        self.steps_since_copy = 0  # Counter for network copy
    
    def remember(self, state, actionA, agentsA_reward, agentsA_deliver, next_state):
        self.memory.append((state, actionA, agentsA_reward, agentsA_deliver, next_state))
        while len(self.memory) > self.replay_buffer_size:
            self.memory.pop(0)  # Remove the oldest experience

    def update_target(self):
        if self.steps_since_copy % self.network_copy_frequency == 0:
            super().update_target()

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return np.random.choice(range(4))  # Random action
        q_values = self.get_qvals(state)
        return np.argmax(q_values)  # Greedy action

    def process_minibatch(self, minibatch):
        states = []
        actions = []
        targets = []
        for state, actionA, agentsA_reward, agentsA_deliver, next_state in minibatch:
            q_values = self.get_qvals(state)
                
            if agentsA_deliver==1:
                q_values[actionA] = agentsA_reward
            else:
                q_values[actionA] = agentsA_reward + self.gamma * self.get_maxQ(next_state)
            
            actions.append(actionA)
            targets.append(q_values[actionA])
        
            states.append(state)
            
        return np.array(states), np.array(actions), np.array(targets)

    def save_model_parameters(self, destination):
        torch.save(self.model2.state_dict(), destination)

    def load_model_parameters(self, path):
        self.model.load_state_dict(torch.load(path))
        self.model2.load_state_dict(torch.load(path))

# %% [markdown]
# #### AGENT B CLASS
#
# The AgentB class is a subclass of the DQN class for type B agents. It represents an agent that can interact with an environment, learn from experiences, and make decisions using Q-learning.
#
# **Attribites**:
# - statespace_size (int): The size of the state space.
# - gamma (float): The discount factor for future rewards.
# - learning_rate (float): The learning rate used for updating the Q-network.
# - start_epsilon (float): The initial exploration rate (epsilon-greedy strategy).
# - epsilon_decay_factor (float): The factor by which epsilon is decayed over time.
# - min_epsilon (float): The minimum value for epsilon.
# - replay_buffer_size (int): The size of the replay buffer for experience replay.
# - batch_size (int): The size of mini-batches for training the network.
# - network_copy_frequency (int): The frequency at which the target network is updated.
#
# **Method**:
# - remember(self, state, actionB, agentsB_reward, agentsB_deliver, next_state): Stores a transition (experience) in the agent's memory.
# - update_target(self): Updates the target Q-network based on the defined network_copy_frequency. It calls the update_target method from the parent class DQN.
# - act(self, state): Decides the action to take in the current state using an epsilon-greedy strategy. It explores with probability epsilon and exploits with probability 1 - epsilon.
# - process_minibatch(self, minibatch): Prepares the data for updating the Q-network based on a mini-batch of experiences.
# - save_model_parameters(self, destination): Saves the model parameters of the agent's Q-network to a specified file.
# - load_model_parameters(self, path): Loads model parameters for the agent's Q-network from a specified file.
#
# **Purpose of this class**:
#
# 1. DQN Implementation: It is an implementation of the Deep Q-Network (`DQN`) algorithm, which is a popular method for solving reinforcement learning problems by approximating the optimal action-value function.
#
# 2. Experience Storage: The `remember` method is responsible for storing experiences (state, action, reward, delivery flag, next state) in the agent's memory. Experience replay is a key feature of DQN algorithms, which helps the agent learn from past experiences.
#
# 3. Epsilon-Greedy Policy: The `act` method implements an epsilon-greedy policy for action selection. It balances exploration (taking random actions) and exploitation (choosing the action with the highest estimated Q-value).
#
# 4. Network Update: The `update_target` method is responsible for updating the target Q-network. In DQN, there are typically two Q-networks: one for learning (the primary network) and one for target values. The target network is periodically updated to stabilize training.
#
# 5. Mini-Batch Processing: The `process_minibatch` method prepares the data for training the Q-network using mini-batches of experiences. It computes target Q-values for each experience, which are used to update the network.

# %%
class AgentB(DQN):
    def __init__(self, statespace_size=12, gamma=0.99, learning_rate=0.997, start_epsilon=1.0,
                 epsilon_decay_factor=0.999, min_epsilon=0.05, replay_buffer_size=10000,
                 batch_size=200, network_copy_frequency=10):
        super().__init__(learning_rate=learning_rate, state_size=statespace_size, action_size=4)  # Call the parent constructor
        self.statespace_size = statespace_size
        self.gamma = gamma
        self.memory = []  # Using a list instead of a deque
        self.epsilon = start_epsilon
        self.epsilon_min = min_epsilon
        self.epsilon_decay_factor = epsilon_decay_factor
        self.replay_buffer_size = replay_buffer_size
        self.batch_size = batch_size
        self.network_copy_frequency = network_copy_frequency
        self.steps_since_copy = 0  # Counter for network copy

    def remember(self, state, actionB, agentsB_reward, agentsB_deliver, next_state):
        self.memory.append((state, actionB, agentsB_reward, agentsB_deliver, next_state))
        while len(self.memory) > self.replay_buffer_size:
            self.memory.pop(0)  # Remove the oldest experience

    def update_target(self):
        if self.steps_since_copy % self.network_copy_frequency == 0:
            super().update_target()

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return np.random.choice(range(4))  # Random action
        q_values = self.get_qvals(state)
        return np.argmax(q_values)  # Greedy action

    def process_minibatch(self, minibatch):
        states = []
        actions = []
        targets = []
        for state, actionB, agentsB_reward, agentsB_deliver, next_state in minibatch:
            q_values = self.get_qvals(state)

            if agentsB_deliver==1:
                q_values[actionB] = agentsB_reward
            else:
                q_values[actionB] = agentsB_reward + self.gamma * self.get_maxQ(next_state)
            
            actions.append(actionB)
            targets.append(q_values[actionB])
        
            states.append(state)
            
        return np.array(states), np.array(actions), np.array(targets)

    def save_model_parameters(self, destination):
        torch.save(self.model2.state_dict(), destination)

    def load_model_parameters(self, path):
        self.model.load_state_dict(torch.load(path))
        self.model2.load_state_dict(torch.load(path))

# %%
def create_one_hot_vector(my_x, my_y, friend_x, friend_y, other1_x, other1_y, other2_x, other2_y, my_flag, friend_flag, other1_flag, other2_flag, grid_size=5):
    
    # Initialize a grid to represent the positions and flags of agents
    grid = np.zeros((grid_size, grid_size, 2, 4))

    # Set the positions of agents from group A
    if my_flag == 0:
        grid[my_x, my_y, 0, 0] = 1
    else:
        grid[my_x, my_y, 1, 0] = 1

    if friend_flag == 0:
        grid[friend_x, friend_y, 0, 1] = 1
    else:
        grid[friend_x, friend_y, 1, 1] = 1

    # Set the positions of agents from group B
    if other1_flag == 0:
        grid[other1_x, other1_y, 0, 2] = 1
    else:
        grid[other1_x, other1_y, 1, 2] = 1

    if other2_flag == 0:
        grid[other2_x, other2_y, 0, 3] = 1
    else:
        grid[other2_x, other2_y, 1, 3] = 1


    # Add a small noise to all the zeros
    noise_level = 1e-6
    grid += np.random.uniform(0, noise_level, size=grid.shape)

    # Flatten the grid into a one-hot vector
    one_hot_vector = grid.reshape(-1)

    return one_hot_vector

# %% [markdown]
# ### Run visualization:
# Runs a visualization of the trained agent's movement in the environment.
#
# The `run_visualisation` function runs a visualization of package delivery episodes using a trained transportation agent. It simulates the agent's actions in the environment and displays the evolving grid at each step of the episode.

# %%
def run_visualisation(agentA, agentB, max_steps=50, size=5):
    #Assumes a fully trained transport agent. 
    #Target network should either have been trained in the preceeding step, or loaded from a pickled pytorch weights file
    env = Environment(size=size,verbose=3)
    # Create a figure and axis outside the loop
    fig, ax = plt.subplots()
    ax.set_facecolor('white')

    # Initialize the plot once with the initial grid
    m = ax.imshow(env.grid, cmap="bone", extent=[0, env.size, 0, env.size])
    snapshots = []
    for step in range(max_steps):
        state = env.get_state()
        stateA1 = np.array([state[0], state[1], state[2], state[3], state[4], state[5], state[6], state[7], state[8], state[9], state[10], state[11]])
        stateA2 = np.array([state[2], state[3], state[0], state[1], state[4], state[5], state[6], state[7], state[9], state[8], state[10], state[11]])
        stateB1 = np.array([state[4],state[5], state[6],state[7], state[0], state[1],state[2],state[3],state[10], state[11], state[8],state[9]])
        stateB2 = np.array([state[6],state[7], state[4],state[5], state[0], state[1],state[2],state[3], state[11], state[10], state[8],state[9]])

        actionA1= np.argmax(agentA.get_qvals(stateA1))
        actionA2 = np.argmax(agentA.get_qvals(stateA2))
        actionB1= np.argmax(agentB.get_qvals(stateB1))
        actionB2 = np.argmax(agentB.get_qvals(stateB2))

        actionA = [env.actions[actionA1], env.actions[actionA2]]
        actionB = [env.actions[actionB1], env.actions[actionB2]]

        _, _, _, _, packages_delivered, terminated  = env.move_agent(actionA, actionB)
        snapshots.append(env.get_grid())

        if terminated or packages_delivered>5:
            break
    print(BOLD, "total packages_delivered", packages_delivered, RESET)
    for s in snapshots:
        env.plot_grid(s, ax)
        # Redraw the plot
        fig.canvas.draw()
        plt.pause(0.2)  # Add a short pause for visualization
    # plt.pause(1.5)
    plt.close()
    return None

# %% [markdown]
# ### Train Function
#
# The purpose of the `train_function` is to begin the training process for two types of agents (A and B) in a package delivery task within a multi-agent reinforcement learning environment. The task involves agent A picking up packages and handing them over to agent B, who is responsible for delivering the packages to their destination. Here's how the function serves this purpose:
#
# 1. **Training Environment (env):** The function takes an environment (`env`) as one of its inputs. This environment represents the simulated world in which agents A and B operate. The environment defines the states, action, rewards of the package delivery task.
#
# 2. **Agent A and Agent B (agentA, agentB):** The function receives two agent types (`agentA` and `agentB`) as inputs. Agent type A handles package pickup, and agent type B manages package delivery.
#
# 3. **Number of Training Episodes (episodes):** The function allows specifying the number of training episodes. An episode represents one complete run of the package delivery task, starting from the initial state and ending when specific termination conditions are met.
#
# 4. **Training Loop:** The core purpose of the function is to run a training loop for a specified number of episodes. In each episode, the following happens:
#
#    a. **Environment Initialization:** The environment is reset, bringing it back to its initial state, and the agents are placed in the environment.
#
#    b. **Agent Interaction:** All agents (2 of Type A and 2 of Type B) interact with the environment by selecting actions based on their current observations and learned policies.
#
#    c. **Experience Collection:** As the agents interact with the environment, they collect experiences, including the current state, the action taken, the received rewards, and the resulting state.
#
#    d. **Replay Memory:** The experiences are stored in the agents' replay memory, which is used for training the DQN models. This replay memory helps stabilize the learning process by randomly sampling past experiences.
#
#    e. **Training:** Both agents may perform training steps using their collected experiences. The DQN models are updated to improve the agents' policies. The training aims to make the agents better at making decisions during the package delivery task.
#
#    f. **Training Metrics:** The function also tracks training metrics such as loss values and empirical rewards (cumulative rewards obtained in each episode). These metrics can be used to monitor the training progress and evaluate the performance of the agents.
#
# 5. **Termination and Exploration:** The function ensures that training episodes are terminated based on certain conditions. It also handles exploration strategy - epsilon-greedy exploration (by adjusting the agents' exploration rate during training using epslion decay).
#
# The `train_function` is responsible for coordinating the training process of two types of agents (A and B) in a multi-agent reinforcement learning environment. It allows the agents to learn optimal policies for the package delivery task, and it tracks training metrics to evaluate their performance and progress.

# %%
def train_function(env, agentA, agentB, episodes=100):
    loss_history = []
    reward_history_A1 = []; reward_history_A2 = []
    reward_history_B1 = []; reward_history_B2 = []
    # distance_history =[]

    for episode in (range(episodes)): #tqdm
        print(BOLD, "episode", episode, RESET)
        env.reset_env()
        state = env.get_state()  # Reset the environment and get the initial state
        
        # steps_to_opt = env.get_optimal_distance()
        steps_in_episode = 0
        # done = False
        terminated = False
        total_reward_A1 = 0; total_reward_A2 = 0
        total_reward_B1 = 0; total_reward_B2 = 0 
        packages_delivered = 0
        episode_losses = []

        if (episode>0 and episode%25 == 0) or (episode == episodes-1):
            agentA.save_model_parameters("logs/target_params_A_{}.pt".format(episode))
            agentB.save_model_parameters("logs/target_params_B_{}.pt".format(episode))

        # print("epsilon", agentA.epsilon)
        
        while (packages_delivered<5 and not terminated):

            stateA1 = np.array([state[0], state[1], state[2], state[3], state[4], state[5], state[6], state[7], state[8], state[9], state[10], state[11]])
            stateA2 = np.array([state[2], state[3], state[0], state[1], state[4], state[5], state[6], state[7], state[9], state[8], state[10], state[11]])
            stateB1 = np.array([state[4],state[5], state[6],state[7], state[0], state[1],state[2],state[3],state[10], state[11], state[8],state[9]])
            stateB2 = np.array([state[6],state[7], state[4],state[5], state[0], state[1],state[2],state[3], state[11], state[10], state[8],state[9]])

            # print("state", state)
            actionA1 = agentA.act(stateA1)
            actionA2 = agentA.act(stateA2)

            actionB1 = agentB.act(stateB1)
            actionB2 = agentB.act(stateB2)

            actionA = [env.actions[actionA1], env.actions[actionA2]]
            actionB = [env.actions[actionB1], env.actions[actionB2]]

            agentsA_reward, agentsB_reward, agentsA_deliver, agentsB_deliver, packages_delivered, terminated = env.move_agent(actionA, actionB)
            
            next_state = env.get_state()
            next_stateA1 = np.array([next_state[0], next_state[1], next_state[2], next_state[3], next_state[4], next_state[5], next_state[6], next_state[7], next_state[8], next_state[9], next_state[10], next_state[11]])
            next_stateA2 = np.array([next_state[2], next_state[3], next_state[0], next_state[1], next_state[4], next_state[5], next_state[6], next_state[7], next_state[9], next_state[8], next_state[10], next_state[11]])
            next_stateB1 = np.array([next_state[4],next_state[5], next_state[6],next_state[7], next_state[0], next_state[1],next_state[2],next_state[3],next_state[10], next_state[11], next_state[8],next_state[9]])
            next_stateB2 = np.array([next_state[6],next_state[7], next_state[4],next_state[5], next_state[0], next_state[1],next_state[2],next_state[3], next_state[11], next_state[10], next_state[8],next_state[9]])

            # next_state, reward, done = env.step(env.actions[action])
            
            #add rewards
            total_reward_A1 += agentsA_reward[0]
            total_reward_B1 += agentsB_reward[0]
            total_reward_A2 += agentsA_reward[1]
            total_reward_B2 += agentsB_reward[1]

            agentA.remember(stateA1, actionA1, agentsA_reward[0], agentsA_deliver[0], next_stateA1)
            agentA.remember(stateA2, actionA2, agentsA_reward[1], agentsA_deliver[1], next_stateA2)
            agentB.remember(stateB1, actionB1, agentsB_reward[0], agentsB_deliver[0], next_stateB1)
            agentB.remember(stateB2, actionB2, agentsB_reward[1], agentsB_deliver[1], next_stateB2)

            state = next_state
            steps_in_episode += 1 

            # Training A
            if len(agentA.memory) > agentA.batch_size:
                minibatch_indices = np.random.choice(len(agentA.memory), agentA.batch_size, replace=False)
                minibatch = [agentA.memory[i] for i in minibatch_indices]
                states_batch, actions_batch, targets_batch = agentA.process_minibatch(minibatch)
                loss = agentA.train_one_step(states_batch, actions_batch, targets_batch)
                episode_losses.append(loss)


            # Training B
            if len(agentB.memory) > agentB.batch_size:
                minibatch_indices = np.random.choice(len(agentB.memory), agentB.batch_size, replace=False)
                minibatch = [agentB.memory[i] for i in minibatch_indices]
                states_batch, actions_batch, targets_batch = agentB.process_minibatch(minibatch)
                loss = agentB.train_one_step(states_batch, actions_batch, targets_batch)
                episode_losses.append(loss)
        
        #Cleanup step

        agentA.epsilon = max(agentA.epsilon * agentA.epsilon_decay_factor, agentA.epsilon_min)
        agentB.epsilon = max(agentB.epsilon * agentB.epsilon_decay_factor, agentB.epsilon_min)

        if len(episode_losses) > 0:
            mean_loss = sum(episode_losses)/len(episode_losses)
        else:
            mean_loss = "n/a"

        agentA.steps_since_copy += 1
        agentA.update_target()
        agentB.steps_since_copy += 1
        agentB.update_target()

        # print("state", state)
        # print(f"Episode: {episode + 1}, Total Reward: {total_reward}, Epsilon: {agent.epsilon} | Loss: {mean_loss}")
        # print(f"Collected: {env.collected} | Terminated: {terminated} | Done: {done}")
        
        # distance_history.append(steps_in_episode - steps_to_opt + 1)
        loss_history.append(mean_loss)
        reward_history_A1.append(total_reward_A1)
        reward_history_A2.append(total_reward_A2)
        reward_history_B1.append(total_reward_B1)
        reward_history_B2.append(total_reward_B2)
        rewards = [reward_history_A1, reward_history_A2, reward_history_B1, reward_history_B2]
    return loss_history, rewards

# %%
# if __name__ == "__main__":
env = Environment(5, verbose=3) # Create the environment

gamma = 0.8; learning_rate = 0.01; epsilon_decay_factor = 0.97; min_epsilon=0.05; replay_buffer_size=10000; batch_size=300; network_copy_frequency=15
episodes = 800

agentA = AgentA(gamma=gamma, learning_rate=learning_rate, epsilon_decay_factor=epsilon_decay_factor,
                 min_epsilon=min_epsilon, replay_buffer_size=replay_buffer_size,
                 batch_size=batch_size, network_copy_frequency=network_copy_frequency)
agentB = AgentB(gamma=gamma, learning_rate=learning_rate, epsilon_decay_factor=epsilon_decay_factor,
                 min_epsilon=min_epsilon, replay_buffer_size=replay_buffer_size,
                 batch_size=batch_size, network_copy_frequency=network_copy_frequency)

# %% [markdown]
# #### Run the below cell for training

# %%
losses, rewards = train_function(env, agentA, agentB, episodes=episodes)
np.save("losses.npy", losses, allow_pickle=False)
np.save("rewards.npy", rewards, allow_pickle=False)
# Out:
#  episode 0
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 996 40
# 	agentsB_reward 964 40
# B1 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 999 102
# 	agentsB_reward 951 142
# B0 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 991 196
# 	agentsB_reward 975 156
# terminated
#  episode 1
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 996 21
# 	agentsB_reward 964 21
# A1 pickup
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 975 16
# 	agentsB_reward 991 37
# A1 pickup
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 996 91
# 	agentsB_reward 964 70
# A0 pickup
# B0 deliver
# terminated
#  episode 2
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 991 22
# 	agentsB_reward 975 22
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 999 86
# 	agentsB_reward 951 86
# A0 pickup
# B0 deliver
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 996 136
# 	agentsB_reward 964 136
# A0 pickup
# terminated
#  episode 3
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 999 40
# 	agentsB_reward 951 40
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 984 106
# 	agentsB_reward 984 106
# A1 pickup
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 999 132
# 	agentsB_reward 951 132
# terminated
#  episode 4
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 1000 51
# 	agentsB_reward 936 51
# A0 pickup
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 991 28
# 	agentsB_reward 975 79
# A1 pickup
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 996 164
# 	agentsB_reward 964 113
# A1 pickup
# A0 pickup
# terminated
#  episode 5
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 964 26
# 	agentsB_reward 996 26
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 991 27
# 	agentsB_reward 975 53
# A1 pickup
# B0 deliver
# A0 pickup
# terminated
#  episode 6
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 964 30
# 	agentsB_reward 996 30
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 984 94
# 	agentsB_reward 984 124
# B1 deliver
# B0 deliver
# terminated
#  episode 7
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 999 13
# 	agentsB_reward 951 13
# A1 pickup
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 951 45
# 	agentsB_reward 999 45
# B0 deliver
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 1000 91
# 	agentsB_reward 936 91
# A1 pickup
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 984 91
# 	agentsB_reward 984 58
# A0 pickup
# A1 pickup
# terminated
#  episode 8
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 975 65
# 	agentsB_reward 991 65
# A1 pickup
# B1 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 951 106
# 	agentsB_reward 999 106
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 975 49
# 	agentsB_reward 991 49
# B1 deliver
# A0 pickup
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 991 74
# 	agentsB_reward 975 66
# terminated
#  episode 9
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 1000 103
# 	agentsB_reward 936 103
# A1 pickup
# A0 pickup
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 964 142
# 	agentsB_reward 996 142
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 964 72
# 	agentsB_reward 996 33
# B1 deliver
# terminated
#  episode 10
# A0 pickup
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 1000 40
# 	agentsB_reward 936 40
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 975 55
# 	agentsB_reward 991 55
# A0 pickup
# B1 deliver
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 991 48
# 	agentsB_reward 975 48
# A1 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 996 62
# 	agentsB_reward 964 62
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 964 59
# 	agentsB_reward 996 88
# B1 deliver
# B0 deliver
#  episode 11
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 996 150
# 	agentsB_reward 964 150
# A1 pickup
# A0 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 964 42
# 	agentsB_reward 996 192
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 964 195
# 	agentsB_reward 996 45
# B1 deliver
# terminated
#  episode 12
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 964 26
# 	agentsB_reward 996 26
# B1 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 984 54
# 	agentsB_reward 984 80
# A1 pickup
# B0 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 964 114
# 	agentsB_reward 996 34
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 951 47
# 	agentsB_reward 999 13
# B0 deliver
# terminated
#  episode 13
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 936 25
# 	agentsB_reward 1000 25
# B0 deliver
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 991 113
# 	agentsB_reward 975 138
# A1 pickup
# B1 deliver
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 951 199
# 	agentsB_reward 999 61
# A0 B0 handover
# 	agentsA_reward 991 62
# 	agentsB_reward 975 175
# B1 deliver
# terminated
#  episode 14
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 975 9
# 	agentsB_reward 991 9
# A0 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 984 44
# 	agentsB_reward 984 53
# A1 pickup
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 996 28
# 	agentsB_reward 964 72
# A0 pickup
# B0 deliver
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 996 120
# 	agentsB_reward 964 67
# A0 B1 handover
# 	agentsA_reward 951 41
# 	agentsB_reward 999 41
# A1 pickup
# B1 deliver
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 984 45
# 	agentsB_reward 984 43
# B1 deliver
#  episode 15
# A1 pickup
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 996 28
# 	agentsB_reward 964 28
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 975 39
# 	agentsB_reward 991 39
# B1 deliver
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 996 24
# 	agentsB_reward 964 24
# A0 pickup
# A1 pickup
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 1000 45
# 	agentsB_reward 936 32
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 991 8
# 	agentsB_reward 975 53
# A1 pickup
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 964 50
# 	agentsB_reward 996 18
# A0 pickup
# B0 deliver
#  episode 16
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 996 13
# 	agentsB_reward 964 13
# A0 pickup
# A1 pickup
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 951 58
# 	agentsB_reward 999 58
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 984 90
# 	agentsB_reward 984 90
# A1 pickup
# A0 pickup
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 964 46
# 	agentsB_reward 996 27
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 975 51
# 	agentsB_reward 991 70
# A0 pickup
# B1 deliver
#  episode 17
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 951 17
# 	agentsB_reward 999 17
# B0 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 964 57
# 	agentsB_reward 996 40
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 975 70
# 	agentsB_reward 991 30
# A1 pickup
# B0 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 991 51
# 	agentsB_reward 975 51
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 951 86
# 	agentsB_reward 999 143
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 964 25
# 	agentsB_reward 996 20
# B0 deliver
#  episode 18
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 996 41
# 	agentsB_reward 964 41
# A0 pickup
# B1 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 996 58
# 	agentsB_reward 964 58
# B1 deliver
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 1000 50
# 	agentsB_reward 936 149
# A1 pickup
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 984 173
# 	agentsB_reward 984 74
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 951 51
# 	agentsB_reward 999 51
# B1 deliver
# terminated
#  episode 19
# A1 pickup
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 984 46
# 	agentsB_reward 984 46
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 991 53
# 	agentsB_reward 975 53
# B0 deliver
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 999 36
# 	agentsB_reward 951 29
# A1 pickup
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 991 5
# 	agentsB_reward 975 41
# B0 deliver
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 936 65
# 	agentsB_reward 1000 36
# B0 deliver
# B1 deliver
#  episode 20
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 996 41
# 	agentsB_reward 964 41
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 964 50
# 	agentsB_reward 996 50
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 936 18
# 	agentsB_reward 1000 9
# B1 deliver
# A1 pickup
# A0 pickup
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 964 38
# 	agentsB_reward 996 56
# A1 B1 handover
# 	agentsA_reward 951 61
# 	agentsB_reward 999 52
# B0 deliver
# B1 deliver
#  episode 21
# A1 pickup
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 964 38
# 	agentsB_reward 996 38
# B1 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 996 59
# 	agentsB_reward 964 59
# A1 pickup
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 975 51
# 	agentsB_reward 991 51
# B1 deliver
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 951 28
# 	agentsB_reward 999 28
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 964 73
# 	agentsB_reward 996 15
# A1 pickup
# B1 deliver
#  episode 22
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 951 49
# 	agentsB_reward 999 49
# B1 deliver
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 964 78
# 	agentsB_reward 996 29
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 936 50
# 	agentsB_reward 1000 21
# B1 deliver
# A0 pickup
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 984 32
# 	agentsB_reward 984 32
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 964 64
# 	agentsB_reward 996 142
# B0 deliver
# B1 deliver
#  episode 23
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 991 52
# 	agentsB_reward 975 52
# A0 pickup
# B1 deliver
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 975 17
# 	agentsB_reward 991 17
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 951 84
# 	agentsB_reward 999 15
# B1 deliver
# A0 pickup
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 964 23
# 	agentsB_reward 996 23
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 964 42
# 	agentsB_reward 996 111
# B0 deliver
#  episode 24
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 975 12
# 	agentsB_reward 991 12
# B1 deliver
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 975 32
# 	agentsB_reward 991 32
# B1 deliver
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 964 54
# 	agentsB_reward 996 10
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 936 28
# 	agentsB_reward 1000 18
# A1 pickup
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 951 47
# 	agentsB_reward 999 101
# B0 deliver
#  episode 25
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 936 26
# 	agentsB_reward 1000 26
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 936 35
# 	agentsB_reward 1000 35
# B1 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 996 92
# 	agentsB_reward 964 101
# A0 pickup
# A1 pickup
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 951 51
# 	agentsB_reward 999 51
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 154
# 	agentsB_reward 1000 2
# B0 deliver
#  episode 26
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 991 12
# 	agentsB_reward 975 12
# A1 pickup
# B0 deliver
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 964 36
# 	agentsB_reward 996 36
# A1 B0 handover
# 	agentsA_reward 951 30
# 	agentsB_reward 999 30
# B1 deliver
# B0 deliver
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 951 42
# 	agentsB_reward 999 42
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 964 56
# 	agentsB_reward 996 20
# A0 pickup
# B1 deliver
#  episode 27
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 951 37
# 	agentsB_reward 999 37
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 42
# 	agentsB_reward 1000 5
# B0 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 1000 11
# 	agentsB_reward 936 53
# A1 pickup
# A0 pickup
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 975 40
# 	agentsB_reward 991 51
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 951 70
# 	agentsB_reward 999 14
# B0 deliver
#  episode 28
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 984 48
# 	agentsB_reward 984 48
# A1 B1 handover
# 	agentsA_reward 936 48
# 	agentsB_reward 1000 48
# B1 deliver
# B0 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 1000 25
# 	agentsB_reward 936 25
# A0 pickup
# B0 deliver
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 951 24
# 	agentsB_reward 999 24
# B0 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 951 62
# 	agentsB_reward 999 13
# B0 deliver
#  episode 29
# A0 pickup
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 984 22
# 	agentsB_reward 984 22
# A0 B0 handover
# 	agentsA_reward 951 23
# 	agentsB_reward 999 23
# B0 deliver
# A1 pickup
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 951 31
# 	agentsB_reward 999 30
# B0 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 951 53
# 	agentsB_reward 999 23
# B0 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 964 48
# 	agentsB_reward 996 79
# B1 deliver
#  episode 30
# A0 pickup
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 964 34
# 	agentsB_reward 996 34
# B1 deliver
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 996 46
# 	agentsB_reward 964 12
# A0 pickup
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 951 31
# 	agentsB_reward 999 65
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 951 25
# 	agentsB_reward 999 25
# B1 deliver
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 996 56
# 	agentsB_reward 964 62
# A0 pickup
# B0 deliver
#  episode 31
# A1 pickup
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 936 34
# 	agentsB_reward 1000 34
# B1 deliver
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 964 124
# 	agentsB_reward 996 90
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 951 103
# 	agentsB_reward 999 13
# A1 pickup
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 936 25
# 	agentsB_reward 1000 149
# B0 deliver
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 964 20
# 	agentsB_reward 996 20
# B1 deliver
#  episode 32
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 999 6
# 	agentsB_reward 951 6
# A0 pickup
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 964 19
# 	agentsB_reward 996 19
# B0 deliver
# A1 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 936 31
# 	agentsB_reward 1000 31
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 20
# 	agentsB_reward 1000 2
# B0 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 964 17
# 	agentsB_reward 996 37
# B1 deliver
#  episode 33
# A0 pickup
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 1000 12
# 	agentsB_reward 936 12
# A1 pickup
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 17
# 	agentsB_reward 1000 17
# B0 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 1000 23
# 	agentsB_reward 936 52
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 975 55
# 	agentsB_reward 991 26
# A0 pickup
# B0 deliver
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 984 13
# 	agentsB_reward 984 13
# B0 deliver
#  episode 34
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 996 6
# 	agentsB_reward 964 6
# A0 pickup
# A1 pickup
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 19
# 	agentsB_reward 1000 19
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 951 31
# 	agentsB_reward 999 6
# B0 deliver
# A1 pickup
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 936 24
# 	agentsB_reward 1000 55
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 984 32
# 	agentsB_reward 984 26
# B0 deliver
#  episode 35
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 999 3
# 	agentsB_reward 951 3
# A0 pickup
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 964 21
# 	agentsB_reward 996 21
# B1 deliver
# B0 deliver
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 951 27
# 	agentsB_reward 999 9
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 951 17
# 	agentsB_reward 999 8
# A0 pickup
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 951 17
# 	agentsB_reward 999 44
# A0 pickup
# A1 pickup
# B1 deliver
#  episode 36
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 991 13
# 	agentsB_reward 975 13
# A0 pickup
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 964 58
# 	agentsB_reward 996 58
# B0 deliver
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 999 44
# 	agentsB_reward 951 115
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 984 13
# 	agentsB_reward 984 57
# B1 deliver
# A0 pickup
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 951 134
# 	agentsB_reward 999 6
# B0 deliver
#  episode 37
# A1 pickup
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 991 17
# 	agentsB_reward 975 17
# A1 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 964 29
# 	agentsB_reward 996 29
# B0 deliver
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 936 35
# 	agentsB_reward 1000 35
# B1 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 951 44
# 	agentsB_reward 999 44
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 951 69
# 	agentsB_reward 999 2
# B1 deliver
#  episode 38
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 984 30
# 	agentsB_reward 984 30
# A0 pickup
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 951 48
# 	agentsB_reward 999 18
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 951 20
# 	agentsB_reward 999 50
# B1 deliver
# A0 pickup
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 984 21
# 	agentsB_reward 984 19
# A0 B0 handover
# 	agentsA_reward 936 23
# 	agentsB_reward 1000 25
# B0 deliver
# A1 pickup
# B1 deliver
#  episode 39
# A0 pickup
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 999 11
# 	agentsB_reward 951 11
# A1 pickup
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 936 29
# 	agentsB_reward 1000 18
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 964 20
# 	agentsB_reward 996 31
# A1 pickup
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 16
# 	agentsB_reward 1000 16
# B0 deliver
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 936 48
# 	agentsB_reward 1000 30
# B0 deliver
#  episode 40
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 999 23
# 	agentsB_reward 951 23
# A0 pickup
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 34
# 	agentsB_reward 1000 11
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 951 16
# 	agentsB_reward 999 5
# B0 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 1000 15
# 	agentsB_reward 936 49
# A0 pickup
# A1 pickup
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 936 38
# 	agentsB_reward 1000 28
# B1 deliver
#  episode 41
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 951 21
# 	agentsB_reward 999 21
# B1 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 991 13
# 	agentsB_reward 975 34
# A0 pickup
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 951 48
# 	agentsB_reward 999 14
# A0 B1 handover
# 	agentsA_reward 975 15
# 	agentsB_reward 991 28
# B0 deliver
# B1 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 951 32
# 	agentsB_reward 999 33
# A1 B1 handover
# 	agentsA_reward 951 33
# 	agentsB_reward 999 32
# B0 deliver
# B1 deliver
#  episode 42
# A1 pickup
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 984 19
# 	agentsB_reward 984 19
# B1 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 999 18
# 	agentsB_reward 951 37
# A0 pickup
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 964 56
# 	agentsB_reward 996 74
# B1 deliver
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 936 105
# 	agentsB_reward 1000 12
# B1 deliver
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 964 29
# 	agentsB_reward 996 17
# B1 deliver
#  episode 43
# A1 pickup
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 984 15
# 	agentsB_reward 984 15
# A1 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 951 21
# 	agentsB_reward 999 21
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 14
# 	agentsB_reward 1000 8
# B0 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 975 24
# 	agentsB_reward 991 16
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 22
# 	agentsB_reward 1000 6
# B0 deliver
#  episode 44
# A0 pickup
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 975 11
# 	agentsB_reward 991 11
# B1 deliver
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 964 16
# 	agentsB_reward 996 27
# B0 deliver
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 936 16
# 	agentsB_reward 1000 16
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 951 45
# 	agentsB_reward 999 34
# B1 deliver
# A1 pickup
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 951 24
# 	agentsB_reward 999 22
# B1 deliver
#  episode 45
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 991 7
# 	agentsB_reward 975 7
# A0 pickup
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 975 12
# 	agentsB_reward 991 12
# A1 pickup
# B0 deliver
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 964 25
# 	agentsB_reward 996 25
# B1 deliver
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 936 29
# 	agentsB_reward 1000 29
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 25
# 	agentsB_reward 1000 2
# B0 deliver
#  episode 46
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 951 14
# 	agentsB_reward 999 14
# B0 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 951 26
# 	agentsB_reward 999 26
# B1 deliver
# A0 pickup
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 975 32
# 	agentsB_reward 991 44
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 48
# 	agentsB_reward 1000 4
# B0 deliver
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 936 21
# 	agentsB_reward 1000 17
# B0 deliver
#  episode 47
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 975 15
# 	agentsB_reward 991 15
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 951 29
# 	agentsB_reward 999 29
# B0 deliver
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 951 38
# 	agentsB_reward 999 38
# A0 B1 handover
# 	agentsA_reward 975 53
# 	agentsB_reward 991 53
# B0 deliver
# B1 deliver
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 936 16
# 	agentsB_reward 1000 16
# B1 deliver
#  episode 48
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 996 8
# 	agentsB_reward 964 8
# A1 B1 handover
# 	agentsA_reward 964 8
# 	agentsB_reward 996 8
# A0 pickup
# B1 deliver
# B0 deliver
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 975 11
# 	agentsB_reward 991 11
# B1 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 951 20
# 	agentsB_reward 999 20
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 18
# 	agentsB_reward 1000 9
# B0 deliver
#  episode 49
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 975 11
# 	agentsB_reward 991 11
# B0 deliver
# A0 pickup
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 951 17
# 	agentsB_reward 999 17
# B0 deliver
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 936 41
# 	agentsB_reward 1000 13
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 951 35
# 	agentsB_reward 999 22
# B0 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 996 33
# 	agentsB_reward 964 11
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 975 14
# 	agentsB_reward 991 77
# B1 deliver
#  episode 50
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 975 13
# 	agentsB_reward 991 13
# A0 pickup
# B0 deliver
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 936 26
# 	agentsB_reward 1000 13
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 18
# 	agentsB_reward 1000 5
# B0 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 936 41
# 	agentsB_reward 1000 36
# B0 deliver
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 936 70
# 	agentsB_reward 1000 34
# B0 deliver
#  episode 51
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 1000 2
# 	agentsB_reward 936 2
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 10
# A1 pickup
# B0 deliver
# B1 deliver
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 951 22
# 	agentsB_reward 999 12
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 936 16
# 	agentsB_reward 1000 24
# B0 deliver
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 951 33
# 	agentsB_reward 999 29
# B0 deliver
#  episode 52
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 964 10
# 	agentsB_reward 996 10
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 964 14
# 	agentsB_reward 996 14
# B1 deliver
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 936 19
# 	agentsB_reward 1000 15
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 951 20
# 	agentsB_reward 999 24
# B0 deliver
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 951 31
# 	agentsB_reward 999 31
# B0 deliver
#  episode 53
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 951 18
# 	agentsB_reward 999 18
# B1 deliver
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 936 45
# 	agentsB_reward 1000 45
# B0 deliver
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 19
# 	agentsB_reward 984 19
# A1 pickup
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 964 55
# 	agentsB_reward 996 9
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 16
# 	agentsB_reward 1000 7
# B0 deliver
#  episode 54
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 991 9
# 	agentsB_reward 975 9
# A1 pickup
# A0 pickup
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 964 19
# 	agentsB_reward 996 19
# A0 B0 handover
# 	agentsA_reward 975 12
# 	agentsB_reward 991 12
# B1 deliver
# B0 deliver
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 975 12
# 	agentsB_reward 991 14
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 964 18
# 	agentsB_reward 996 16
# B0 deliver
#  episode 55
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 991 7
# 	agentsB_reward 975 7
# A1 pickup
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 936 30
# 	agentsB_reward 1000 30
# B1 deliver
# A1 pickup
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 975 91
# 	agentsB_reward 991 54
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 936 58
# 	agentsB_reward 1000 4
# B1 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 999 10
# 	agentsB_reward 951 101
# A0 pickup
# B0 deliver
#  episode 56
# A1 pickup
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 936 30
# 	agentsB_reward 1000 30
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 936 33
# 	agentsB_reward 1000 3
# B1 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 951 20
# 	agentsB_reward 999 17
# B1 deliver
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 975 35
# 	agentsB_reward 991 18
# B1 deliver
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 951 23
# 	agentsB_reward 999 5
# B1 deliver
#  episode 57
# A1 pickup
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 936 31
# 	agentsB_reward 1000 31
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 936 40
# 	agentsB_reward 1000 40
# B0 deliver
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 964 33
# 	agentsB_reward 996 24
# B0 deliver
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 951 35
# 	agentsB_reward 999 35
# B0 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 936 98
# 	agentsB_reward 1000 39
# B0 deliver
#  episode 58
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 996 11
# 	agentsB_reward 964 11
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 991 14
# 	agentsB_reward 975 14
# A1 pickup
# B1 deliver
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 11
# 	agentsB_reward 1000 8
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 951 10
# 	agentsB_reward 999 2
# B0 deliver
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 936 15
# 	agentsB_reward 1000 15
# B0 deliver
#  episode 59
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 936 14
# 	agentsB_reward 1000 14
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 975 19
# 	agentsB_reward 991 19
# B1 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 951 21
# 	agentsB_reward 999 21
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 21
# 	agentsB_reward 1000 5
# B0 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 984 61
# 	agentsB_reward 984 56
# A0 pickup
# B0 deliver
#  episode 60
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A0 pickup
# B1 deliver
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 975 9
# 	agentsB_reward 991 9
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 951 22
# 	agentsB_reward 999 5
# B1 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 936 26
# 	agentsB_reward 1000 43
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 29
# 	agentsB_reward 1000 8
# B0 deliver
#  episode 61
# A1 pickup
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 936 17
# 	agentsB_reward 1000 17
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 936 23
# 	agentsB_reward 1000 23
# B0 deliver
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 975 16
# 	agentsB_reward 991 22
# B1 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 999 7
# 	agentsB_reward 951 23
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 964 7
# 	agentsB_reward 996 14
# B0 deliver
# B1 deliver
#  episode 62
# A1 pickup
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 936 11
# 	agentsB_reward 1000 11
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 936 15
# 	agentsB_reward 1000 15
# B0 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 951 17
# 	agentsB_reward 999 17
# B1 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 951 35
# 	agentsB_reward 999 35
# B0 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 964 38
# 	agentsB_reward 996 38
# A0 pickup
# B1 deliver
#  episode 63
# A0 pickup
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 936 16
# 	agentsB_reward 1000 16
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 951 17
# 	agentsB_reward 999 1
# B1 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 951 15
# 	agentsB_reward 999 32
# B0 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 999 41
# 	agentsB_reward 951 40
# A1 pickup
# A0 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 951 42
# 	agentsB_reward 999 42
# A1 B1 handover
# 	agentsA_reward 936 18
# 	agentsB_reward 1000 18
# B0 deliver
# B1 deliver
#  episode 64
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 936 17
# 	agentsB_reward 1000 17
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 951 27
# 	agentsB_reward 999 27
# B1 deliver
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 996 22
# 	agentsB_reward 964 32
# A0 pickup
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 964 43
# 	agentsB_reward 996 33
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 964 15
# 	agentsB_reward 996 15
# A1 pickup
# B0 deliver
#  episode 65
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 951 9
# 	agentsB_reward 999 9
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 951 15
# 	agentsB_reward 999 6
# B0 deliver
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 964 25
# 	agentsB_reward 996 34
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 936 25
# 	agentsB_reward 1000 6
# B1 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 991 14
# 	agentsB_reward 975 33
# A1 pickup
# A0 pickup
# B0 deliver
#  episode 66
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 936 11
# 	agentsB_reward 1000 11
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 951 13
# 	agentsB_reward 999 2
# B0 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 964 37
# 	agentsB_reward 996 50
# B1 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 951 63
# 	agentsB_reward 999 61
# B0 deliver
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 936 66
# 	agentsB_reward 1000 42
# B0 deliver
#  episode 67
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 1000 6
# 	agentsB_reward 936 6
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 975 11
# 	agentsB_reward 991 17
# B0 deliver
# B1 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 936 27
# 	agentsB_reward 1000 21
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 964 11
# 	agentsB_reward 996 11
# B1 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 936 15
# 	agentsB_reward 1000 16
# B0 deliver
#  episode 68
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 936 16
# 	agentsB_reward 1000 16
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 17
# 	agentsB_reward 1000 1
# B0 deliver
# A0 pickup
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 984 48
# 	agentsB_reward 984 48
# A1 pickup
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 54
# 	agentsB_reward 1000 5
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 951 12
# 	agentsB_reward 999 7
# B0 deliver
#  episode 69
# A0 pickup
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 936 15
# 	agentsB_reward 1000 15
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 16
# 	agentsB_reward 1000 1
# B0 deliver
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 951 52
# 	agentsB_reward 999 51
# B0 deliver
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 936 35
# 	agentsB_reward 1000 35
# B0 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 964 139
# 	agentsB_reward 996 53
# B0 deliver
#  episode 70
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 975 15
# 	agentsB_reward 991 15
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 19
# 	agentsB_reward 1000 4
# B0 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 936 13
# 	agentsB_reward 1000 28
# B1 deliver
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 951 17
# 	agentsB_reward 999 26
# B0 deliver
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 975 41
# 	agentsB_reward 991 32
# A0 pickup
# A1 pickup
# B1 deliver
#  episode 71
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 991 4
# 	agentsB_reward 975 4
# A1 B1 handover
# 	agentsA_reward 991 4
# 	agentsB_reward 975 4
# A0 pickup
# A1 pickup
# B0 deliver
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 936 11
# 	agentsB_reward 1000 11
# A1 B1 handover
# 	agentsA_reward 936 11
# 	agentsB_reward 1000 11
# B0 deliver
# B1 deliver
# A0 pickup
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 951 166
# 	agentsB_reward 999 166
# A0 B1 handover
# 	agentsA_reward 951 167
# 	agentsB_reward 999 167
# B0 deliver
#  episode 72
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 964 10
# 	agentsB_reward 996 10
# B0 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 936 26
# 	agentsB_reward 1000 26
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 39
# 	agentsB_reward 1000 3
# B0 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 936 16
# 	agentsB_reward 1000 13
# B0 deliver
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 984 50
# 	agentsB_reward 984 102
# A1 B0 handover
# 	agentsA_reward 951 67
# 	agentsB_reward 999 54
# B1 deliver
#  episode 73
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 991 6
# 	agentsB_reward 975 6
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 999 5
# 	agentsB_reward 951 11
# B0 deliver
# A0 pickup
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 936 19
# 	agentsB_reward 1000 8
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 936 9
# 	agentsB_reward 1000 1
# B1 deliver
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 936 18
# 	agentsB_reward 1000 31
# B0 deliver
#  episode 74
# A1 pickup
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 996 11
# 	agentsB_reward 964 11
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 936 15
# 	agentsB_reward 1000 15
# B0 deliver
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 10
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 996 6
# 	agentsB_reward 964 12
# B1 deliver
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 936 16
# 	agentsB_reward 1000 10
# B1 deliver
# B0 deliver
#  episode 75
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 936 16
# 	agentsB_reward 1000 16
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 17
# 	agentsB_reward 1000 1
# B0 deliver
# A0 pickup
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 999 9
# 	agentsB_reward 951 9
# A1 pickup
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 951 19
# 	agentsB_reward 999 35
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 951 12
# 	agentsB_reward 999 12
# B0 deliver
#  episode 76
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# A0 pickup
# A1 pickup
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 975 9
# 	agentsB_reward 991 18
# A0 B0 handover
# 	agentsA_reward 936 19
# 	agentsB_reward 1000 10
# B0 deliver
# B1 deliver
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 951 13
# 	agentsB_reward 999 12
# B0 deliver
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 964 21
# 	agentsB_reward 996 22
# B1 deliver
#  episode 77
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 964 14
# 	agentsB_reward 996 14
# A1 B0 handover
# 	agentsA_reward 951 18
# 	agentsB_reward 999 18
# B1 deliver
# B0 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 951 13
# 	agentsB_reward 999 9
# A1 pickup
# B0 deliver
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 951 17
# 	agentsB_reward 999 21
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 964 13
# 	agentsB_reward 996 5
# A1 pickup
# B1 deliver
#  episode 78
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 975 8
# 	agentsB_reward 991 8
# A0 B1 handover
# 	agentsA_reward 975 9
# 	agentsB_reward 991 9
# B0 deliver
# B1 deliver
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 951 12
# 	agentsB_reward 999 12
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 13
# 	agentsB_reward 1000 2
# B0 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 964 16
# 	agentsB_reward 996 27
# A0 pickup
# B1 deliver
#  episode 79
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 936 12
# 	agentsB_reward 1000 12
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 951 14
# 	agentsB_reward 999 14
# B1 deliver
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 13
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 951 21
# 	agentsB_reward 999 19
# A1 pickup
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 951 16
# 	agentsB_reward 999 8
# B1 deliver
#  episode 80
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 951 8
# 	agentsB_reward 999 8
# A1 pickup
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 975 16
# 	agentsB_reward 991 8
# A0 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 996 13
# 	agentsB_reward 964 21
# A1 pickup
# A0 pickup
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 951 18
# 	agentsB_reward 999 23
# A1 B0 handover
# 	agentsA_reward 936 24
# 	agentsB_reward 1000 19
# B0 deliver
# B1 deliver
#  episode 81
# A1 pickup
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 936 11
# 	agentsB_reward 1000 11
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 936 12
# 	agentsB_reward 1000 1
# B1 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 951 44
# 	agentsB_reward 999 56
# B0 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 964 54
# 	agentsB_reward 996 53
# B1 deliver
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 936 28
# 	agentsB_reward 1000 19
# B1 deliver
#  episode 82
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 975 6
# 	agentsB_reward 991 6
# B0 deliver
# A1 pickup
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 999 8
# 	agentsB_reward 951 14
# A1 pickup
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 936 22
# 	agentsB_reward 1000 8
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 936 15
# 	agentsB_reward 1000 7
# B1 deliver
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 936 16
# 	agentsB_reward 1000 9
# B1 deliver
#  episode 83
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 951 13
# 	agentsB_reward 999 13
# A1 B1 handover
# 	agentsA_reward 936 13
# 	agentsB_reward 1000 13
# B1 deliver
# B0 deliver
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 996 9
# 	agentsB_reward 964 9
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 991 11
# 	agentsB_reward 975 11
# A1 pickup
# B1 deliver
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 13
# 	agentsB_reward 1000 11
# A1 B1 handover
# 	agentsA_reward 936 11
# 	agentsB_reward 1000 13
# B0 deliver
# B1 deliver
#  episode 84
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 951 8
# 	agentsB_reward 999 8
# A0 pickup
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 964 15
# 	agentsB_reward 996 7
# A1 pickup
# B0 deliver
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 999 7
# 	agentsB_reward 951 22
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 936 17
# 	agentsB_reward 1000 10
# B0 deliver
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 936 9
# 	agentsB_reward 1000 6
# B0 deliver
#  episode 85
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 951 12
# 	agentsB_reward 999 12
# A1 B1 handover
# 	agentsA_reward 964 13
# 	agentsB_reward 996 13
# B0 deliver
# B1 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 1000 11
# 	agentsB_reward 936 11
# A0 pickup
# A1 pickup
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 22
# 	agentsB_reward 1000 12
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 13
# 	agentsB_reward 1000 1
# B0 deliver
#  episode 86
# A0 pickup
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 975 10
# 	agentsB_reward 991 10
# A0 B0 handover
# 	agentsA_reward 936 12
# 	agentsB_reward 1000 12
# B0 deliver
# B1 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 951 16
# 	agentsB_reward 999 16
# B1 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 936 25
# 	agentsB_reward 1000 25
# B0 deliver
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 964 20
# 	agentsB_reward 996 9
# B0 deliver
#  episode 87
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 996 7
# 	agentsB_reward 964 7
# A0 pickup
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 21
# 	agentsB_reward 1000 21
# A1 B1 handover
# 	agentsA_reward 936 28
# 	agentsB_reward 1000 28
# B0 deliver
# B1 deliver
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 999 24
# 	agentsB_reward 951 24
# A0 pickup
# A1 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 936 10
# 	agentsB_reward 1000 34
# A1 B1 handover
# 	agentsA_reward 936 34
# 	agentsB_reward 1000 10
# B0 deliver
# B1 deliver
#  episode 88
# A0 pickup
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 996 7
# 	agentsB_reward 964 7
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 951 12
# 	agentsB_reward 999 12
# B0 deliver
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 936 10
# 	agentsB_reward 1000 10
# B0 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 936 18
# 	agentsB_reward 1000 13
# B0 deliver
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 996 42
# 	agentsB_reward 964 29
# A1 pickup
# B0 deliver
#  episode 89
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 975 9
# 	agentsB_reward 991 9
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 975 13
# 	agentsB_reward 991 13
# A1 pickup
# B1 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 13
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 936 17
# 	agentsB_reward 1000 13
# B0 deliver
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 936 14
# 	agentsB_reward 1000 14
# B0 deliver
#  episode 90
# A1 pickup
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 951 12
# 	agentsB_reward 999 12
# B1 deliver
# B0 deliver
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 936 14
# 	agentsB_reward 1000 10
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 17
# 	agentsB_reward 1000 7
# B0 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 951 15
# 	agentsB_reward 999 8
# B0 deliver
#  episode 91
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 936 14
# 	agentsB_reward 1000 14
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 15
# 	agentsB_reward 1000 1
# B0 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 964 15
# 	agentsB_reward 996 14
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 964 17
# 	agentsB_reward 996 32
# B1 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 996 8
# 	agentsB_reward 964 8
# A1 pickup
# A0 pickup
# B0 deliver
#  episode 92
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 991 6
# 	agentsB_reward 975 6
# A0 pickup
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 17
# 	agentsB_reward 1000 11
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 13
# 	agentsB_reward 1000 2
# B0 deliver
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 991 13
# 	agentsB_reward 975 13
# A0 pickup
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 951 13
# 	agentsB_reward 999 45
# A1 B0 handover
# 	agentsA_reward 936 29
# 	agentsB_reward 1000 14
# B0 deliver
# B1 deliver
#  episode 93
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 964 9
# 	agentsB_reward 996 9
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 18
# 	agentsB_reward 1000 9
# A1 pickup
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 984 13
# 	agentsB_reward 984 22
# A1 pickup
# B1 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 936 12
# 	agentsB_reward 1000 16
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 18
# 	agentsB_reward 1000 2
# B0 deliver
#  episode 94
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# A1 B1 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# A0 pickup
# A1 pickup
# B1 deliver
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 975 13
# 	agentsB_reward 991 13
# B1 deliver
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 951 11
# 	agentsB_reward 999 11
# A1 pickup
# B1 deliver
#  episode 95
# A0 pickup
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 1000 6
# 	agentsB_reward 936 6
# A0 B1 handover
# 	agentsA_reward 984 7
# 	agentsB_reward 984 7
# A1 pickup
# A0 pickup
# B1 deliver
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 11
# 	agentsB_reward 1000 11
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 12
# 	agentsB_reward 1000 2
# B0 deliver
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 951 17
# 	agentsB_reward 999 15
# B0 deliver
#  episode 96
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 964 9
# 	agentsB_reward 996 9
# A1 B1 handover
# 	agentsA_reward 964 10
# 	agentsB_reward 996 10
# B0 deliver
# B1 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 951 15
# 	agentsB_reward 999 15
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 951 18
# 	agentsB_reward 999 4
# B0 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 936 17
# 	agentsB_reward 1000 13
# B0 deliver
#  episode 97
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 936 10
# 	agentsB_reward 1000 10
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 12
# 	agentsB_reward 1000 2
# B0 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 975 18
# 	agentsB_reward 991 16
# A1 pickup
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 984 20
# 	agentsB_reward 984 32
# A0 pickup
# A1 pickup
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 936 14
# 	agentsB_reward 1000 10
# B1 deliver
#  episode 98
# A1 pickup
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 991 8
# 	agentsB_reward 975 8
# A1 B0 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# A0 pickup
# A1 pickup
# B0 deliver
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 936 13
# 	agentsB_reward 1000 12
# A1 B1 handover
# 	agentsA_reward 936 12
# 	agentsB_reward 1000 13
# B0 deliver
# B1 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 999 13
# 	agentsB_reward 951 13
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 975 6
# 	agentsB_reward 991 19
# B0 deliver
#  episode 99
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 975 6
# 	agentsB_reward 991 6
# A0 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# B0 deliver
# A1 pickup
# B1 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 991 8
# 	agentsB_reward 975 8
# A1 pickup
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 951 14
# 	agentsB_reward 999 14
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 951 10
# 	agentsB_reward 999 2
# B1 deliver
#  episode 100
# A1 pickup
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 1000 7
# 	agentsB_reward 936 7
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 936 13
# 	agentsB_reward 1000 13
# B0 deliver
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 936 9
# 	agentsB_reward 1000 3
# B0 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 996 10
# 	agentsB_reward 964 16
# A0 pickup
# A1 pickup
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 951 16
# 	agentsB_reward 999 9
# A1 B0 handover
# 	agentsA_reward 936 10
# 	agentsB_reward 1000 17
# B0 deliver
# B1 deliver
#  episode 101
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 984 6
# 	agentsB_reward 984 6
# A0 pickup
# A1 pickup
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 936 15
# 	agentsB_reward 1000 9
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 964 13
# 	agentsB_reward 996 19
# B0 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 975 13
# 	agentsB_reward 991 9
# B0 deliver
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 964 14
# 	agentsB_reward 996 18
# B1 deliver
#  episode 102
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 996 6
# 	agentsB_reward 964 6
# A1 pickup
# A0 pickup
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 15
# 	agentsB_reward 1000 9
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 10
# 	agentsB_reward 1000 1
# B0 deliver
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 984 12
# 	agentsB_reward 984 12
# A0 pickup
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 23
# 	agentsB_reward 1000 10
# B0 deliver
#  episode 103
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 10
# A0 B1 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# A1 pickup
# B0 deliver
# A0 pickup
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 pickup
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 951 12
# 	agentsB_reward 999 12
# B1 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 951 14
# 	agentsB_reward 999 14
# B0 deliver
#  episode 104
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 936 12
# 	agentsB_reward 1000 12
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 13
# 	agentsB_reward 1000 1
# B0 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 984 12
# 	agentsB_reward 984 11
# A1 B1 handover
# 	agentsA_reward 984 13
# 	agentsB_reward 984 26
# A0 pickup
# A1 pickup
# B0 deliver
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 936 13
# 	agentsB_reward 1000 13
# B0 deliver
#  episode 105
# A0 pickup
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 10
# A0 B0 handover
# 	agentsA_reward 936 12
# 	agentsB_reward 1000 12
# B0 deliver
# A1 pickup
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 991 7
# 	agentsB_reward 975 5
# A0 pickup
# A1 pickup
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 12
# 	agentsB_reward 1000 12
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 18
# 	agentsB_reward 1000 1
# B0 deliver
#  episode 106
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 936 10
# 	agentsB_reward 1000 10
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 12
# 	agentsB_reward 1000 2
# B0 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 984 14
# 	agentsB_reward 984 12
# A1 B1 handover
# 	agentsA_reward 984 12
# 	agentsB_reward 984 24
# A0 pickup
# A1 pickup
# B0 deliver
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A0 pickup
# B0 deliver
#  episode 107
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 6
# 	agentsB_reward 984 6
# A0 B1 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 10
# A1 pickup
# B0 deliver
# A0 pickup
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 951 13
# 	agentsB_reward 999 13
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 12
# 	agentsB_reward 1000 3
# B0 deliver
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 936 15
# 	agentsB_reward 1000 12
# B0 deliver
#  episode 108
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 975 7
# 	agentsB_reward 991 7
# A1 pickup
# B1 deliver
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 936 15
# 	agentsB_reward 1000 8
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 951 12
# 	agentsB_reward 999 19
# B0 deliver
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 996 10
# 	agentsB_reward 964 10
# A0 pickup
# A1 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 936 15
# 	agentsB_reward 1000 15
# B0 deliver
#  episode 109
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 964 9
# 	agentsB_reward 996 9
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 951 14
# 	agentsB_reward 999 14
# B1 deliver
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 12
# 	agentsB_reward 984 12
# A1 pickup
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 964 13
# 	agentsB_reward 996 13
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 964 10
# 	agentsB_reward 996 4
# B1 deliver
#  episode 110
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 999 7
# 	agentsB_reward 951 7
# A1 pickup
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# A1 pickup
# B0 deliver
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 936 14
# 	agentsB_reward 1000 14
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 13
# 	agentsB_reward 1000 3
# B0 deliver
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 975 14
# 	agentsB_reward 991 24
# A1 B0 handover
# 	agentsA_reward 984 13
# 	agentsB_reward 984 13
# B1 deliver
#  episode 111
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 975 12
# 	agentsB_reward 991 12
# B0 deliver
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 936 21
# 	agentsB_reward 1000 9
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 951 14
# 	agentsB_reward 999 5
# B0 deliver
# A0 pickup
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# A0 B1 handover
# 	agentsA_reward 975 18
# 	agentsB_reward 991 39
# A1 pickup
# B0 deliver
# B1 deliver
#  episode 112
# A1 pickup
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 10
# A1 B1 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 10
# A0 pickup
# B0 deliver
# B1 deliver
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 975 9
# 	agentsB_reward 991 9
# A1 B1 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# A0 pickup
# B0 deliver
# A1 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 975 12
# 	agentsB_reward 991 12
# B0 deliver
#  episode 113
# A1 pickup
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 984 12
# 	agentsB_reward 984 12
# A1 B0 handover
# 	agentsA_reward 975 12
# 	agentsB_reward 991 12
# B0 deliver
# A0 pickup
# B1 deliver
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 936 12
# 	agentsB_reward 1000 12
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 13
# ...
# 	agentsB_reward 984 12
# A0 pickup
# B0 deliver
# A1 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 B1 handover
# 	agentsA_reward 975 9
# 	agentsB_reward 991 9
# A0 pickup
# B0 deliver
#  episode 767
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# B1 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 951 18
# 	agentsB_reward 999 18
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 975 11
# 	agentsB_reward 991 11
# A1 pickup
# A0 pickup
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# A0 B1 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# A1 pickup
# B0 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# B1 deliver
#  episode 768
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 991 4
# 	agentsB_reward 975 4
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 975 8
# 	agentsB_reward 991 8
# A1 pickup
# B0 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 975 9
# 	agentsB_reward 991 9
# B1 deliver
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# B1 deliver
#  episode 769
# A0 pickup
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 10
# A0 B0 handover
# 	agentsA_reward 975 12
# 	agentsB_reward 991 12
# A1 pickup
# B0 deliver
# B1 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 7
# A0 B1 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 11
# B0 deliver
# A0 pickup
# A1 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 10
# A1 B1 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 8
# A1 pickup
# B0 deliver
# B1 deliver
#  episode 770
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 984 12
# 	agentsB_reward 984 12
# A1 B1 handover
# 	agentsA_reward 984 13
# 	agentsB_reward 984 13
# A0 pickup
# B0 deliver
# A1 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# B0 deliver
# A1 pickup
# B1 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 9
# A0 B1 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 9
# B0 deliver
#  episode 771
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 999 4
# 	agentsB_reward 951 4
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# B0 deliver
# A0 pickup
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 951 9
# 	agentsB_reward 999 9
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 975 10
# 	agentsB_reward 991 10
# A1 pickup
# B1 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# A0 B1 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# A1 pickup
# B0 deliver
#  episode 772
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# A1 B0 handover
# 	agentsA_reward 984 13
# 	agentsB_reward 984 13
# A0 pickup
# A1 pickup
# B1 deliver
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 964 10
# 	agentsB_reward 996 8
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 951 11
# 	agentsB_reward 999 13
# B1 deliver
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 10
# A1 pickup
# A1 B1 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# B0 deliver
#  episode 773
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 999 3
# 	agentsB_reward 951 3
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 984 7
# 	agentsB_reward 984 7
# B0 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 951 8
# 	agentsB_reward 999 8
# B1 deliver
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 7
# A1 pickup
# A0 pickup
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 984 13
# 	agentsB_reward 984 17
# A0 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 pickup
# B1 deliver
#  episode 774
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 7
# 	agentsB_reward 984 7
# A0 B1 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 10
# B0 deliver
# A1 pickup
# A0 pickup
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 10
# A0 B1 handover
# 	agentsA_reward 975 9
# 	agentsB_reward 991 9
# A1 pickup
# B0 deliver
# B1 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A0 B1 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# A1 pickup
# B0 deliver
#  episode 775
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 B0 handover
# 	agentsA_reward 991 9
# 	agentsB_reward 975 9
# A0 pickup
# A1 pickup
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 964 9
# 	agentsB_reward 996 9
# A0 pickup
# B0 deliver
# B1 deliver
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 7
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 991 11
# 	agentsB_reward 975 13
# B0 deliver
#  episode 776
# A0 pickup
# A1 pickup
# A1 B0 handover
# 	agentsA_reward 999 5
# 	agentsB_reward 951 5
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 975 9
# 	agentsB_reward 991 9
# B0 deliver
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 951 8
# 	agentsB_reward 999 8
# A0 pickup
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 7
# A1 pickup
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 15
# B0 deliver
# A1 pickup
# B1 deliver
#  episode 777
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 984 6
# 	agentsB_reward 984 6
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 975 10
# 	agentsB_reward 991 10
# B1 deliver
# A1 pickup
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 936 13
# 	agentsB_reward 1000 9
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 13
# 	agentsB_reward 1000 4
# B0 deliver
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 984 13
# 	agentsB_reward 984 26
# A1 B0 handover
# 	agentsA_reward 984 12
# 	agentsB_reward 984 12
# B1 deliver
#  episode 778
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# A1 B0 handover
# 	agentsA_reward 975 12
# 	agentsB_reward 991 12
# A0 pickup
# B1 deliver
# B0 deliver
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# A1 B0 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# A0 pickup
# A1 pickup
# B0 deliver
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 975 10
# 	agentsB_reward 991 7
# B0 deliver
#  episode 779
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 996 5
# 	agentsB_reward 964 5
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 10
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 964 8
# 	agentsB_reward 996 8
# B0 deliver
# A0 pickup
# B1 deliver
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 7
# A1 B1 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 13
# A0 pickup
# B0 deliver
# A1 pickup
# B1 deliver
#  episode 780
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 pickup
# A0 pickup
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 936 16
# 	agentsB_reward 1000 8
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 936 14
# 	agentsB_reward 1000 22
# B0 deliver
# A1 pickup
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 975 14
# 	agentsB_reward 991 14
# B1 deliver
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 964 15
# 	agentsB_reward 996 15
# A1 B1 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# B0 deliver
#  episode 781
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 984 5
# 	agentsB_reward 984 5
# A0 pickup
# A1 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 14
# A1 B1 handover
# 	agentsA_reward 984 14
# 	agentsB_reward 984 9
# A0 pickup
# A1 pickup
# B0 deliver
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 pickup
# B0 deliver
# B1 deliver
#  episode 782
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 984 6
# 	agentsB_reward 984 6
# A0 pickup
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 951 11
# 	agentsB_reward 999 11
# B0 deliver
# A0 B0 handover
# 	agentsA_reward 964 11
# 	agentsB_reward 996 6
# A1 pickup
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 16
# A0 pickup
# A1 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 10
# A1 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# B0 deliver
#  episode 783
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 6
# 	agentsB_reward 984 6
# A0 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 pickup
# B0 deliver
# A0 pickup
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A0 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 pickup
# B0 deliver
# A0 pickup
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 975 10
# 	agentsB_reward 991 10
# A0 B1 handover
# 	agentsA_reward 975 9
# 	agentsB_reward 991 9
# B0 deliver
#  episode 784
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 964 9
# 	agentsB_reward 996 9
# A1 B1 handover
# 	agentsA_reward 964 13
# 	agentsB_reward 996 13
# B0 deliver
# A0 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 10
# A1 pickup
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 10
# B0 deliver
# A1 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 975 10
# 	agentsB_reward 991 10
# A1 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# B0 deliver
#  episode 785
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 pickup
# B0 deliver
# B1 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A0 B1 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 10
# A1 pickup
# A0 pickup
# B0 deliver
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 975 9
# 	agentsB_reward 991 9
# A0 B1 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# B0 deliver
#  episode 786
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 984 6
# 	agentsB_reward 984 6
# A1 pickup
# A0 pickup
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 936 17
# 	agentsB_reward 1000 11
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 936 12
# 	agentsB_reward 1000 1
# B1 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 999 22
# 	agentsB_reward 951 40
# A0 pickup
# B0 deliver
# A1 B0 handover
# 	agentsA_reward 936 31
# 	agentsB_reward 1000 8
# B0 deliver
#  episode 787
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 984 7
# 	agentsB_reward 984 7
# A1 B0 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# B1 deliver
# A0 pickup
# A1 pickup
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# A1 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A0 pickup
# B1 deliver
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# B1 deliver
#  episode 788
# A1 pickup
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 999 5
# 	agentsB_reward 951 5
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 975 12
# 	agentsB_reward 991 12
# B1 deliver
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 964 11
# 	agentsB_reward 996 11
# A0 pickup
# B1 deliver
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# A1 B1 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 10
# A0 pickup
# B0 deliver
# A1 pickup
# B1 deliver
#  episode 789
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 996 5
# 	agentsB_reward 964 5
# A0 B1 handover
# 	agentsA_reward 991 8
# 	agentsB_reward 975 8
# A1 pickup
# A0 pickup
# B0 deliver
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 984 7
# 	agentsB_reward 984 10
# A1 B1 handover
# 	agentsA_reward 964 12
# 	agentsB_reward 996 9
# A0 pickup
# B0 deliver
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 6
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 12
# B1 deliver
#  episode 790
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 975 7
# 	agentsB_reward 991 7
# A0 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# B0 deliver
# A0 pickup
# B1 deliver
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 9
# A1 B1 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 10
# B0 deliver
# A0 pickup
# B1 deliver
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 975 11
# 	agentsB_reward 991 11
# A1 B1 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# B0 deliver
#  episode 791
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 1000 6
# 	agentsB_reward 936 6
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 984 5
# 	agentsB_reward 984 11
# B1 deliver
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 951 15
# 	agentsB_reward 999 9
# B0 deliver
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 975 9
# 	agentsB_reward 991 9
# A1 pickup
# B0 deliver
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# A0 B0 handover
# 	agentsA_reward 975 10
# 	agentsB_reward 991 10
# A1 pickup
# B1 deliver
#  episode 792
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 975 10
# 	agentsB_reward 991 10
# A1 B1 handover
# 	agentsA_reward 975 10
# 	agentsB_reward 991 10
# B0 deliver
# B1 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# A1 B1 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# A0 pickup
# A1 pickup
# B0 deliver
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 B1 handover
# 	agentsA_reward 975 9
# 	agentsB_reward 991 9
# A0 pickup
# A1 pickup
# B0 deliver
# B1 deliver
#  episode 793
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 6
# 	agentsB_reward 984 6
# A0 B1 handover
# 	agentsA_reward 991 8
# 	agentsB_reward 975 8
# A1 pickup
# B0 deliver
# A0 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 984 7
# 	agentsB_reward 984 9
# A1 B1 handover
# 	agentsA_reward 975 11
# 	agentsB_reward 991 9
# A0 pickup
# B0 deliver
# B1 deliver
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# A1 B1 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# B0 deliver
#  episode 794
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 984 6
# 	agentsB_reward 984 6
# A1 B0 handover
# 	agentsA_reward 991 6
# 	agentsB_reward 975 6
# A1 pickup
# A0 pickup
# B1 deliver
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 B0 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# A0 pickup
# B1 deliver
# A1 pickup
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A0 pickup
# B1 deliver
#  episode 795
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 999 6
# 	agentsB_reward 951 6
# A0 pickup
# A0 B0 handover
# 	agentsA_reward 964 7
# 	agentsB_reward 996 13
# B1 deliver
# A1 B1 handover
# 	agentsA_reward 964 15
# 	agentsB_reward 996 9
# B0 deliver
# B1 deliver
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 984 10
# 	agentsB_reward 984 10
# A1 B1 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# A0 pickup
# B0 deliver
# A1 pickup
# B1 deliver
#  episode 796
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# A1 pickup
# A0 pickup
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 964 15
# 	agentsB_reward 996 15
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 964 11
# 	agentsB_reward 996 11
# A1 pickup
# B1 deliver
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 964 14
# 	agentsB_reward 996 14
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 964 13
# 	agentsB_reward 996 13
# B1 deliver
#  episode 797
# A0 pickup
# A0 B1 handover
# 	agentsA_reward 999 5
# 	agentsB_reward 951 5
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# B1 deliver
# A0 B1 handover
# 	agentsA_reward 951 8
# 	agentsB_reward 999 8
# A1 pickup
# B0 deliver
# B1 deliver
# A1 B0 handover
# 	agentsA_reward 975 10
# 	agentsB_reward 991 10
# A0 pickup
# B0 deliver
# A0 B1 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 11
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# B1 deliver
#  episode 798
# A0 pickup
# A1 pickup
# A0 B1 handover
# 	agentsA_reward 964 9
# 	agentsB_reward 996 9
# B1 deliver
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 936 16
# 	agentsB_reward 1000 7
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 984 12
# 	agentsB_reward 984 21
# A1 pickup
# A0 pickup
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 984 12
# 	agentsB_reward 984 12
# A0 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 pickup
# B1 deliver
# A0 pickup
# B0 deliver
#  episode 799
# A1 pickup
# A0 pickup
# A1 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A0 B1 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# A1 pickup
# B1 deliver
# B0 deliver
# A0 pickup
# A1 B1 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 8
# A0 B0 handover
# 	agentsA_reward 984 11
# 	agentsB_reward 984 12
# A1 pickup
# B1 deliver
# A0 pickup
# B0 deliver
# A1 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A0 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 pickup
# B1 deliver

# %% [markdown]
# #### Run the below cell for visualisation

# %%
# check visualization
agentA.load_model_parameters(path = 'logs/target_params_A_799.pt')
agentB.load_model_parameters(path = 'logs/target_params_B_799.pt')
run_visualisation(agentA, agentB)
# Out:
# A0 pickup
# A1 pickup
# A0 B0 handover
# 	agentsA_reward 984 7
# 	agentsB_reward 984 7
# A1 B1 handover
# 	agentsA_reward 984 9
# 	agentsB_reward 984 9
# A0 pickup
# B0 deliver
# A1 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A0 pickup
# B0 deliver
# A1 pickup
# B1 deliver
# A0 B0 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A1 B1 handover
# 	agentsA_reward 984 8
# 	agentsB_reward 984 8
# A0 pickup
# B0 deliver
# A1 pickup
# B1 deliver
#  total packages_delivered 6

# %%
rewards = np.load("rewards.npy", allow_pickle=False)
losses = np.load("losses.npy", allow_pickle=False)

# %%
round_losses = [round(loss, 2) for loss in losses if loss != "n/a"]
plt.plot(round_losses, label='Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.legend()
plt.show()

# %%
agents = ['Agent A1', 'Agent A2', 'Agent B1', 'Agent B2']

for i in range(len(rewards)):
    plt.plot(rewards[i], label=agents[i])

plt.xlabel('Episode')
plt.ylabel('Reward')
plt.legend()
plt.title('Reward History for All Agents')
plt.show()
